# %%
# Eromosele Smart-Ochie
## 20120612109
### eromosele.smart-ochie@pau.edu.ng
#### Exercise 1

# %% [markdown]
# **A python program to get the difference between a given number and 17. if the number is greater than 17 return double the absoulte difference.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x=int(input("A given number"))
y=x-17
if y > 17:
    print(y*2)
else:
    y<17
    print(abs(y))
# Out:
# A given number40
# 46

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# **Python program to calculate the sum of three given numbers, if the values are equal then return thrice of their sum**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=int(input("state your number"))
b=int(input("state your number"))
c=int(input("state your number"))
if a==b==c:
    print((a+b+c)*3)
else:
    a<b<c
    print(a+b+c)
# Out:
# state your number2
# state your number3
# state your number4
# 9

# %% [markdown]
# ### Exercise III

# %% [markdown]
# **A python program which will return true if the two given integer values are equal or their sum or difference is 5**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
t=int(input("the number u want"))
s=int(input("the number u like"))
if t==s:
    print("true")
elif t+s==5:
    print("true")
elif t-s==5:
    print("true")
# Out:
# the number u want3
# the number u like2
# true

# %% [markdown]
# #### Exercise IV

# %% [markdown]
# **A python program to sort three integers without using conditional statements and loops.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=float(input("the number that u like"))
b=float(input("the number that u like"))
c=float(input("the number that u like"))
d=min(a,b,c)
f=max(a,b,c)
e=(((a+b+c)-d)-f)
print("Minimum value", d)
print("middle value", e)
print("Maximum value", f)
# Out:
# the number that u like2
# the number that u like3
# the number that u like4
# Minimum value 2.0
# middle value 3.0
# Maximum value 4.0

# %% [markdown]
# ##### Exercise V

# %% [markdown]
# **A python function that takes a positive integer and returns the sum of the cube of all the positive integers smaller than the specified number**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = int(input("enter number u like"))
b= list(range(1,a))
c = 0;
for i in b:
    d = i**3
    c = c + d
print(c)
# Out:
# enter number u like6
# 225
